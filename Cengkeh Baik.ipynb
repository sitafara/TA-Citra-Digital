# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./baik1.png')

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
plt.imshow(img)

# %%
lu=img[...,0].flatten()
hist_h = plt.hist(lu,256)
plt.show()

# %%
lu=img[...,1].flatten()
hist_s = plt.hist(lu,256)
plt.show()

# %%
hist_h[1]
# Out:
# array([  0.        ,   0.81640625,   1.6328125 ,   2.44921875,
#          3.265625  ,   4.08203125,   4.8984375 ,   5.71484375,
#          6.53125   ,   7.34765625,   8.1640625 ,   8.98046875,
#          9.796875  ,  10.61328125,  11.4296875 ,  12.24609375,
#         13.0625    ,  13.87890625,  14.6953125 ,  15.51171875,
#         16.328125  ,  17.14453125,  17.9609375 ,  18.77734375,
#         19.59375   ,  20.41015625,  21.2265625 ,  22.04296875,
#         22.859375  ,  23.67578125,  24.4921875 ,  25.30859375,
#         26.125     ,  26.94140625,  27.7578125 ,  28.57421875,
#         29.390625  ,  30.20703125,  31.0234375 ,  31.83984375,
#         32.65625   ,  33.47265625,  34.2890625 ,  35.10546875,
#         35.921875  ,  36.73828125,  37.5546875 ,  38.37109375,
#         39.1875    ,  40.00390625,  40.8203125 ,  41.63671875,
#         42.453125  ,  43.26953125,  44.0859375 ,  44.90234375,
#         45.71875   ,  46.53515625,  47.3515625 ,  48.16796875,
# ...

# %%
hist_s[1]
# Out:
# array([  7.        ,   7.85546875,   8.7109375 ,   9.56640625,
#         10.421875  ,  11.27734375,  12.1328125 ,  12.98828125,
#         13.84375   ,  14.69921875,  15.5546875 ,  16.41015625,
#         17.265625  ,  18.12109375,  18.9765625 ,  19.83203125,
#         20.6875    ,  21.54296875,  22.3984375 ,  23.25390625,
#         24.109375  ,  24.96484375,  25.8203125 ,  26.67578125,
#         27.53125   ,  28.38671875,  29.2421875 ,  30.09765625,
#         30.953125  ,  31.80859375,  32.6640625 ,  33.51953125,
#         34.375     ,  35.23046875,  36.0859375 ,  36.94140625,
#         37.796875  ,  38.65234375,  39.5078125 ,  40.36328125,
#         41.21875   ,  42.07421875,  42.9296875 ,  43.78515625,
#         44.640625  ,  45.49609375,  46.3515625 ,  47.20703125,
#         48.0625    ,  48.91796875,  49.7734375 ,  50.62890625,
#         51.484375  ,  52.33984375,  53.1953125 ,  54.05078125,
#         54.90625   ,  55.76171875,  56.6171875 ,  57.47265625,
# ...

# %%
ukuran_baik = 0
warna_baik = 0

for index,value in enumerate(hist_h[1]):
    if (value >= 0.01 and value <= 0.07) and (hist_s[1][index] >= 0.1 and hist_s[1][index] <= 0.6):
        ukuran_baik += 1
    
    if (value >= 0.6 and value <= 1) and (hist_s[1][index] >= 0 and hist_s[1][index] <= 0.15):
        warna_baik += 1
ukuran_baik = ukuran_baik/hist_h[1].shape[0]*100
#print(ukuran_baik)
#print(warna_baik)

ukuran = False
warna = False
if ukuran_baik>0.01:
    ukuran = True
    
if warna_baik<500:
    warna = True
    
if ukuran==True and warna==True:
    print("Cengkeh Baik")
else:
    print("Cengkeh Buruk")
# Out:
# Cengkeh Buruk

# %% [markdown]
# Hasil cengkeh buruk karena resolusi gambar berbeda dengan resolusi gambar pada paper
